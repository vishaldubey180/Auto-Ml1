# %% [markdown]
# # AUTO-SKLEARN

# %% [markdown]
# ![1.JPG](attachment:1.JPG)

# %% [markdown]
# - It is an automated machine learning package based on sklearn
#
# - with the success of ML , a borad range of ml appplication letdo the evergreen demand of ML application that can be used by non-expert
#
# - to effective in practice such system names to automatically choose it good algorithm respective hyperparameter

# %% [markdown]
# ![2.JPG](attachment:2.JPG)

# %% [markdown]
# - Auto-sklearn uses 15 classifiers
# - 14 featyre preprocessing methods
# - 4 data preprocessing methods
# - 110 hyperparameters

# %% [markdown]
# ![3.JPG](attachment:3.JPG)

# %% [markdown]
# - we can se all the 15 classification algorithm
#
# - This system of auto-sklearn improves the existing automl methods
# - autosklearn team first review the formation of auto-ml as combined algorithm selection and hyperparametr optmization problem , which is CASH

# %% [markdown]
# ![4.JPG](attachment:4.JPG)

# %% [markdown]
# So this above problem can be solved by bayseian  optimization
# and first problem can be solved with the help of second problem depend on whetehr their hyperparameters are tunned properly
#
# fortunately the two problem can be effectively  tackled as single structure join optimization problem
#
# auto-sklearn freeze the ml user from ml algorithm selection and hyperparametr tunning
#
# it laverage recent advantages in bayesian optimization , Meta learning and ensemble construction

# %% [markdown]
# ![5.JPG](attachment:5.JPG)

# %% [markdown]
# ![6.JPG](attachment:6.JPG)

# %% [markdown]
# Auto-sklearn is based on the defination of CASH problem
#
# The same idea behind the azure auto ml they consider the problem of simultaneously selecting the learning algorithm and setting hyperparametr

# %% [markdown]
# ![7.JPG](attachment:7.JPG)

# %% [markdown]
# So the CASH problem first tackled by Tree -based bayesian optimization
#
# in a nutshell bayesian optimization model fits probabilistic model to capture the relationship between hyperparameter setting and their major performance
# then it uses tos elect the most promising hyperparameter and evaluate that hyperparameter setting
#
# Well bayesian optimization based on gausian process model performs best in low dimension problem with numerical hyperparameter
#
# Tree based bayesian optimization models has been shown to be more successful in high dimesnion , structured problem such as CASH problem

# %% [markdown]
# ![8.JPG](attachment:8.JPG)

# %% [markdown]
# Meta-learning, in the machine learning context, is the use of machine learning algorithms to assist in the training and optimization of other machine learning models. As meta-learning is becoming more and more popular and more meta-learning techniques are being developed, it’s beneficial to have an understanding of what meta-learning is and to have a sense of the various ways it can be applied

# %% [markdown]
# ![9.JPG](attachment:9.JPG)

# %% [markdown]
# Tree based optimization tool is a python automated ML tool that optimizes ML pipelines using genetic programming

# %% [markdown]
# ![10.JPG](attachment:10.JPG)

# %% [markdown]
# Autmated ML systems are helpful data scince assistant ,  design tool stand data for noval featurs selct appropriate supervise algorithm and optimize the parameters
#
# For this purpose TPOT was generated using strongly typed geneatic programming
#
# ---------------------------------------------------------------------------------------
#
# Automated Machine Learning (AutoML) refers to techniques for automatically discovering well-performing models for predictive modeling tasks with very little user involvement.
#
# TPOT is an open-source library for performing AutoML in Python. It makes use of the popular Scikit-Learn machine learning library for data transforms and machine learning algorithms and uses a Genetic Programming stochastic global search procedure to efficiently discover a top-performing model pipeline for a given dataset.
#
# -------------------------------------------------------------------------------------------
#
#
# TPOT for Automated Machine Learning
# Tree-based Pipeline Optimization Tool, or TPOT for short, is a Python library for automated machine learning.
#
# TPOT uses a tree-based structure to represent a model pipeline for a predictive modeling problem, including data preparation and modeling algorithms and model hyperparameters.
#
# … an evolutionary algorithm called the Tree-based Pipeline Optimization Tool (TPOT) that automatically designs and optimizes machine learning pipelines.
#
# — Evaluation of a Tree-based Pipeline Optimization Tool for Automating Data Science, 2016.
#
# An optimization procedure is then performed to find a tree structure that performs best for a given dataset. Specifically, a genetic programming algorithm, designed to perform a stochastic global optimization on programs represented as trees.
#
# TPOT uses a version of genetic programming to automatically design and optimize a series of data transformations and machine learning models that attempt to maximize the classification accuracy for a given supervised learning data set.
#
# — Evaluation of a Tree-based Pipeline Optimization Tool for Automating Data Science, 2016.
#
# The figure below taken from the TPOT paper shows the elements involved in the pipeline search, including data cleaning, feature selection, feature processing, feature construction, model selection, and hyperparameter optimization.

# %% [markdown]
# ![11.JPG](attachment:11.JPG)

# %% [markdown]
# # Genetic programming
#
# In artificial intelligence, genetic programming (GP) is a technique of evolving programs, starting from a population of unfit (usually random) programs, fit for a particular task by applying operations analogous to natural genetic processes to the population of programs.

# %% [markdown]
# ![12.JPG](attachment:12.JPG)

# %% [markdown]
# genetic programming is poerful method for automatically generating the compouter programs

# %% [markdown]
# ![13.JPG](attachment:13.JPG)

# %% [markdown]
# ![14.JPG](attachment:14.JPG)

# %% [markdown]
# # Autokeras

# %% [markdown]
# AutoML refers to techniques for automatically discovering the best-performing model for a given dataset.
#
# When applied to neural networks, this involves both discovering the model architecture and the hyperparameters used to train the model, generally referred to as neural architecture search.
#
# AutoKeras is an open-source library for performing AutoML for deep learning models. The search is performed using so-called Keras models via the TensorFlow tf.keras API.
#
# It provides a simple and effective approach for automatically finding top-performing models for a wide range of predictive modeling tasks, including tabular or so-called structured classification and regression datasets.

# %% [markdown]
# --------------------------------------------------------------------------
#
# autokeras system is designed with concise interface for the people not specialised in compuer programing and data scince
#
# the goal of autokeras to enable the people with limited ML background knowledge to use ML models easily

# %% [markdown]
# ![16.JPG](attachment:16.JPG)

# %% [markdown]
# ![17.JPG](attachment:17.JPG)

# %% [markdown]
# NASS is process of automating the architecture enginerring i.e finding the decision of our ML model where we need to provide NASS system with daatset and a task whetehr classification or regression and it will give us the archtecture
# and this archtecture will perform best among all other architecture
# NASS can be seen as subfield of automl and has significant overlap with hyper parametr optimization
#
# work has been done on automated ml model selection and  autonated hyperparameter tunning in the context of deep learning and nural architecture search system
#
# nural architecture search system  aims to serach best neural network architecture for the given learning task and dataset has been become efeective automl

# %% [markdown]
# ![18.JPG](attachment:18.JPG)

# %% [markdown]
# ![19.JPG](attachment:19.JPG)

# %% [markdown]
# ![20.JPG](attachment:20.JPG)

# %% [markdown]
# ![21.JPG](attachment:21.JPG)

# %% [markdown]
# ![22.JPG](attachment:22.JPG)

# %% [markdown]
# ![23.JPG](attachment:23.JPG)
